# %% [markdown]
# Here's a "vanilla" 🍦 feed-forward neural network with [logistic activation functions](https://en.wikipedia.org/wiki/Logistic_function) and [softmax](https://en.wikipedia.org/wiki/Softmax_function) applied to the output layer.

# %% [markdown]
# ![Screenshot 2023-01-10 at 13.22.25.png](attachment:dd7212d2-8dc5-4e12-bcb0-70b641404c23.png)

# %% [markdown]
# Given the following X and y tensors representing training data,

# %%
import torch

# Make data
torch.manual_seed(4321)
X = torch.rand(size=(8,2))
y = torch.randint(low=0, high=3, size=(8,))

print(X)
print(y)
# Out:
# tensor([[0.1255, 0.5377],
#         [0.6564, 0.0365],
#         [0.5837, 0.7018],
#         [0.3068, 0.9500],
#         [0.4321, 0.2946],
#         [0.6015, 0.1762],
#         [0.9945, 0.3177],
#         [0.9886, 0.3911]])
# tensor([0, 2, 2, 0, 2, 2, 0, 1])

# %% [markdown]
# **calculate**:
#
# + the predictions (forward pass)
# + the loss using categorical cross entropy
# + the gradient of the loss with respect to the weights and biases

# %% [markdown]
# **Logist function**:
#
# ![Screenshot 2023-01-10 at 13.26.46.png](attachment:8dd4489a-167d-41aa-8562-96192bca7c67.png)

# %% [markdown]
# **Sigmoid function**:
#
# ![Screenshot 2023-01-10 at 13.25.32.png](attachment:ce74a430-25ad-40b0-8b0d-46139fd90753.png)

# %% [markdown]
# **Categorical Cross Entropy Loss**:
#
# ![Screenshot 2023-01-10 at 13.25.45.png](attachment:b1677ef0-bfb7-4c16-8133-25bbc005a21b.png)
